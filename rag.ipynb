# %%
import streamlit as st
from PyPDF2 import PdfReader
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from dotenv.ipython import load_dotenv
from langchain_openai import ChatOpenAI

# %%
load_dotenv(override=True)
from langchain_text_splitters import(
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,)

# %%
prompt_template="""
Answer the following question based only on the provided context in the form of a poem -like the percy jackson prophecies-

<context>
{context}
</contxt>
<question>
<input>
</question>
"""
{input}

llm=ChatOpenAI(model="gpt-4o",temperature=0)

# %%
def main():
    st.set_page_config(page_title="Delphi reg chat", layout="wide")
    st.subheader("Retrieval Augmented generation",divider="blue")
    
    with st.sidebar:
      st.sidebar.title("chat nul PT")
      st.image("rag.png")    
      pdf_docs=st.file_uploader(label="Load your pdfs",accept_multiple_files=True)
      if st.button("Submit"):
         with st.spinner("Loading"):
            content =""
            for pdf in pdf_docs:
               reader = PdfReader(pdf)
               for page in reader.pages:
                content += page.extract_text()

            splitter= RecursiveCharacterTextSplitter.from_tiktoken_encoder(
               chunk_size=512, chunk_overlap=16
            )

            chunks= splitter.split_text(content)
            st.write(chunks)

            embedding_model= OpenAIEmbeddings()
            vector_strore = Chroma.from_texts(
                chunks,
                embedding_model,
                collection_name="data_collection",
            )
            retriever = vector_store.as_retriever(
                kwargs={"k": 5},
            )
            st.session_state.retriever= retriever
st.subheader("Delphi chatbot")
user_question = st.text_input("Ask your question")
if user_question:
    context_docs= st.session_state.retriever.invoke(user_question)
    context_list= [d.page_content for d in context_docs]
    context_text=".".join(context_list)

    prompt= llm.invoke(prompt)

    st.write(resp.content)


if __name__ == "__main__": main()
# Out:
# 2026-04-06 17:35:30.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:30.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:31.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:32.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:32.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 17:35:32.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
